# %%
# !pip install -q condacolab
import condacolab
condacolab.install_anaconda()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Load and create environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content'

# %%
# Execution time 4m 18s
# %cp -av /content/drive/MyDrive/'Colab Notebooks'/benchmarking-gnns /content
# Out:
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns' -> '/content/benchmarking-gnns'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_superpixels_graph_classification.py' -> '/content/benchmarking-gnns/main_superpixels_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_CSL_graph_classification.py' -> '/content/benchmarking-gnns/main_CSL_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_superpixels_graph_classification.ipynb' -> '/content/benchmarking-gnns/main_superpixels_graph_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.gitignore' -> '/content/benchmarking-gnns/.gitignore'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_molecules_graph_regression.py' -> '/content/benchmarking-gnns/main_molecules_graph_regression.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/environment_cpu.yml' -> '/content/benchmarking-gnns/environment_cpu.yml'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_GraphTheoryProp_multitask.ipynb' -> '/content/benchmarking-gnns/main_GraphTheoryProp_multitask.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_TUs_graph_classification.py' -> '/content/benchmarking-gnns/main_TUs_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_TSP_edge_classification.py' -> '/content/benchmarking-gnns/main_TSP_edge_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_molecules_graph_regression.ipynb' -> '/content/benchmarking-gnns/main_molecules_graph_regression.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_CYCLES_graph_classification.py' -> '/content/benchmarking-gnns/main_CYCLES_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_COLLAB_edge_classification.py' -> '/content/benchmarking-gnns/main_COLLAB_edge_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_CSL_graph_classification.ipynb' -> '/content/benchmarking-gnns/main_CSL_graph_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_GraphTheoryProp_multitask.py' -> '/content/benchmarking-gnns/main_GraphTheoryProp_multitask.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_TUs_graph_classification.ipynb' -> '/content/benchmarking-gnns/main_TUs_graph_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_TSP_edge_classification.ipynb' -> '/content/benchmarking-gnns/main_TSP_edge_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_COLLAB_edge_classification.ipynb' -> '/content/benchmarking-gnns/main_COLLAB_edge_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/README.md' -> '/content/benchmarking-gnns/README.md'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/LICENSE' -> '/content/benchmarking-gnns/LICENSE'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_CYCLES_graph_classification.ipynb' -> '/content/benchmarking-gnns/main_CYCLES_graph_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/environment_gpu.yml' -> '/content/benchmarking-gnns/environment_gpu.yml'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.DS_Store' -> '/content/benchmarking-gnns/.DS_Store'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers' -> '/content/benchmarking-gnns/layers'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/mlp_readout_layer.py' -> '/content/benchmarking-gnns/layers/mlp_readout_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/gin_layer.py' -> '/content/benchmarking-gnns/layers/gin_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/three_wl_gnn_layers.py' -> '/content/benchmarking-gnns/layers/three_wl_gnn_layers.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/gated_gcn_layer.py' -> '/content/benchmarking-gnns/layers/gated_gcn_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/gat_layer.py' -> '/content/benchmarking-gnns/layers/gat_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/graphsage_layer.py' -> '/content/benchmarking-gnns/layers/graphsage_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/ring_gnn_equiv_layer.py' -> '/content/benchmarking-gnns/layers/ring_gnn_equiv_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/gmm_layer.py' -> '/content/benchmarking-gnns/layers/gmm_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/gcn_layer.py' -> '/content/benchmarking-gnns/layers/gcn_layer.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__' -> '/content/benchmarking-gnns/layers/__pycache__'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/graphsage_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/graphsage_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gmm_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gmm_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/mlp_readout_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/mlp_readout_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gcn_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gcn_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gin_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gin_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/three_wl_gnn_layers.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/three_wl_gnn_layers.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gated_gcn_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gated_gcn_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gat_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gat_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/ring_gnn_equiv_layer.cpython-38.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/ring_gnn_equiv_layer.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gated_gcn_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gated_gcn_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/mlp_readout_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/mlp_readout_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gcn_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gcn_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gat_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gat_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/graphsage_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/graphsage_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gin_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gin_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/gmm_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/gmm_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/ring_gnn_equiv_layer.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/ring_gnn_equiv_layer.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/layers/__pycache__/three_wl_gnn_layers.cpython-37.pyc' -> '/content/benchmarking-gnns/layers/__pycache__/three_wl_gnn_layers.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train' -> '/content/benchmarking-gnns/train'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_TUs_graph_classification.py' -> '/content/benchmarking-gnns/train/train_TUs_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_CYCLES_graph_classification.py' -> '/content/benchmarking-gnns/train/train_CYCLES_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/metrics.py' -> '/content/benchmarking-gnns/train/metrics.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_CSL_graph_classification.py' -> '/content/benchmarking-gnns/train/train_CSL_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_SBMs_node_classification.py' -> '/content/benchmarking-gnns/train/train_SBMs_node_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_GraphTheoryProp_multitask.py' -> '/content/benchmarking-gnns/train/train_GraphTheoryProp_multitask.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_TSP_edge_classification.py' -> '/content/benchmarking-gnns/train/train_TSP_edge_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_COLLAB_edge_classification.py' -> '/content/benchmarking-gnns/train/train_COLLAB_edge_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_superpixels_graph_classification.py' -> '/content/benchmarking-gnns/train/train_superpixels_graph_classification.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/train_molecules_graph_regression.py' -> '/content/benchmarking-gnns/train/train_molecules_graph_regression.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/__pycache__' -> '/content/benchmarking-gnns/train/__pycache__'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/__pycache__/train_SBMs_node_classification.cpython-38.pyc' -> '/content/benchmarking-gnns/train/__pycache__/train_SBMs_node_classification.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/__pycache__/metrics.cpython-38.pyc' -> '/content/benchmarking-gnns/train/__pycache__/metrics.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/__pycache__/train_SBMs_node_classification.cpython-37.pyc' -> '/content/benchmarking-gnns/train/__pycache__/train_SBMs_node_classification.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/train/__pycache__/metrics.cpython-37.pyc' -> '/content/benchmarking-gnns/train/__pycache__/metrics.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs' -> '/content/benchmarking-gnns/configs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GCN_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GCN_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GCN_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GCN_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_MoNet_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_MoNet_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GIN_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GIN_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GCN_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GCN_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_MoNet_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_MoNet_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GraphSage_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GraphSage_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GatedGCN_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GatedGCN_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GAT_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GAT_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_edgereprfeat.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_edgereprfeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GraphSage_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GraphSage_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GAT_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GAT_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_isotropic.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_isotropic.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_RingGNN_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_RingGNN_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_RingGNN_ZINC_L8_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_RingGNN_ZINC_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GAT_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GAT_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_RingGNN_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_RingGNN_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_3WLGNN_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_3WLGNN_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_CLUSTER_PE_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_CLUSTER_PE_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_PE_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_PE_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_MoNet_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_MoNet_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GIN_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GIN_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_PATTERN_L8_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_PATTERN_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GAT_edgereprfeat.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GAT_edgereprfeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GCN_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GCN_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GCN_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GCN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GAT_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GAT_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/GraphTheoryProp_multitask_GIN_GraphTheoryProp_100k.json' -> '/content/benchmarking-gnns/configs/GraphTheoryProp_multitask_GIN_GraphTheoryProp_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GAT_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GAT_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GCN_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GCN_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_MLP_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_MLP_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_MLP_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_MLP_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_MoNet_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_MoNet_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_3WLGNN_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_3WLGNN_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GatedGCN_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GatedGCN_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_edgereprfeat.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_edgereprfeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_isotropic.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_isotropic.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GIN_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GIN_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_MLP_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_MLP_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CYCLES_graph_classification_GatedGCN_CYCLES_100k.json' -> '/content/benchmarking-gnns/configs/CYCLES_graph_classification_GatedGCN_CYCLES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_PATTERN_L8_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_PATTERN_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GatedGCN_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GatedGCN_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_CIFAR10_L8_500k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_CIFAR10_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/GraphTheoryProp_multitask_GatedGCN_PE_GraphTheoryProp_100k.json' -> '/content/benchmarking-gnns/configs/GraphTheoryProp_multitask_GatedGCN_PE_GraphTheoryProp_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GatedGCN_ZINC_PE_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GatedGCN_ZINC_PE_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_isotropic.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_isotropic.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_RingGNN_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_RingGNN_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GIN_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GIN_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_MNIST_L8_500k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_MNIST_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_MLP_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_MLP_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GCN_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GCN_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_edgefeat.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_edgefeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CYCLES_graph_classification_GatedGCN_PE_CYCLES_100k.json' -> '/content/benchmarking-gnns/configs/CYCLES_graph_classification_GatedGCN_PE_CYCLES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_MoNet_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_MoNet_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_edgereprfeat.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GatedGCN_edgereprfeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GIN_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GIN_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_RingGNN_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_RingGNN_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GIN_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GIN_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MLP_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MLP_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GIN_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GIN_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_MF.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_MF.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GatedGCN_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GatedGCN_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GCN_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GCN_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GraphSage_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_MLP_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_MLP_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GatedGCN_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GatedGCN_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GAT_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GAT_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_RingGNN_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_RingGNN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_MLP_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_MLP_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GAT_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GAT_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GAT_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GAT_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GraphSage_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GraphSage_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_CLUSTER_L8_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_CLUSTER_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_RingGNN_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GIN_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GIN_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_MLP_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_MLP_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GCN_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GCN_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_CLUSTER_L8_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_CLUSTER_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_3WLGNN_ZINC_L8_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_3WLGNN_ZINC_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GCN_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GCN_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_edgefeat.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_edgefeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_MoNet_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_MoNet_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_3WLGNN_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_3WLGNN_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_edgefeat.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_edgefeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GAT_isotropic.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GAT_isotropic.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_3WLGNN_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_3WLGNN_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GatedGCN_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GatedGCN_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GAT_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GAT_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_3WLGNN_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_3WLGNN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GatedGCN_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GatedGCN_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_MLP_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_MLP_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GCN_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GCN_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GraphSage_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GraphSage_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GraphSage_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GraphSage_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/GraphTheoryProp_multitask_GatedGCN_GraphTheoryProp_100k.json' -> '/content/benchmarking-gnns/configs/GraphTheoryProp_multitask_GatedGCN_GraphTheoryProp_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_RingGNN_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_RingGNN_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MLP_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MLP_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GIN_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GIN_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GAT_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GAT_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_MLP_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_MLP_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GCN_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GCN_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_isotropic.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_isotropic.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GCN_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GCN_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MLP_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MLP_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_MNIST_L8_500k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_MNIST_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_MoNet_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_MoNet_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/GraphTheoryProp_multitask_GIN_PE_GraphTheoryProp_100k.json' -> '/content/benchmarking-gnns/configs/GraphTheoryProp_multitask_GIN_PE_GraphTheoryProp_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GIN_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GIN_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_MoNet_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_MoNet_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_edgereprfeat.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GatedGCN_edgereprfeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GraphSage_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GraphSage_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GraphSage_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GraphSage_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_MoNet_PROTEINS_full_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_MoNet_PROTEINS_full_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GatedGCN_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GatedGCN_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MLP_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MLP_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GIN_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GIN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GraphSage_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GraphSage_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_RingGNN_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_RingGNN_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GAT_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GAT_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_CLUSTER_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_CLUSTER_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_edgefeat.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GraphSage_edgefeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_3WLGNN_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_3WLGNN_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GraphSage_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GraphSage_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GatedGCN_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GatedGCN_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_MLP_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_MLP_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_3WLGNN_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GAT_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GAT_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_PATTERN_PE_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GatedGCN_PATTERN_PE_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_GCN_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_GCN_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GAT_edgefeat.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GAT_edgefeat.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CYCLES_graph_classification_GIN_PE_CYCLES_100k.json' -> '/content/benchmarking-gnns/configs/CYCLES_graph_classification_GIN_PE_CYCLES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GIN_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GIN_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_40k.json' -> '/content/benchmarking-gnns/configs/COLLAB_edge_classification_GAT_40k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_PATTERN_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_PATTERN_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_GIN_CSL_PE_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_GIN_CSL_PE_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CYCLES_graph_classification_GIN_CYCLES_100k.json' -> '/content/benchmarking-gnns/configs/CYCLES_graph_classification_GIN_CYCLES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GCN_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GCN_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_MoNet_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_MoNet_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_MoNet_CIFAR10_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_MoNet_CIFAR10_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_CIFAR10_L8_500k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_3WLGNN_CIFAR10_L8_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GIN_ZINC_500k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GIN_ZINC_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/CSL_graph_classification_3WLGNN_CSL_100k.json' -> '/content/benchmarking-gnns/configs/CSL_graph_classification_3WLGNN_CSL_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_MoNet_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_RingGNN_ENZYMES_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_RingGNN_ENZYMES_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/superpixels_graph_classification_MLP_MNIST_100k.json' -> '/content/benchmarking-gnns/configs/superpixels_graph_classification_MLP_MNIST_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_PATTERN_100k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_RingGNN_PATTERN_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_GraphSage_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_GraphSage_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/SBMs_node_clustering_GIN_CLUSTER_500k.json' -> '/content/benchmarking-gnns/configs/SBMs_node_clustering_GIN_CLUSTER_500k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TSP_edge_classification_GAT_100k.json' -> '/content/benchmarking-gnns/configs/TSP_edge_classification_GAT_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/TUs_graph_classification_3WLGNN_DD_100k.json' -> '/content/benchmarking-gnns/configs/TUs_graph_classification_3WLGNN_DD_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/configs/molecules_graph_regression_GAT_ZINC_100k.json' -> '/content/benchmarking-gnns/configs/molecules_graph_regression_GAT_ZINC_100k.json'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/utils' -> '/content/benchmarking-gnns/utils'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/utils/__pycache__' -> '/content/benchmarking-gnns/utils/__pycache__'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/utils/__pycache__/cleaner_main.cpython-38.pyc' -> '/content/benchmarking-gnns/utils/__pycache__/cleaner_main.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/utils/__pycache__/cleaner_main.cpython-37.pyc' -> '/content/benchmarking-gnns/utils/__pycache__/cleaner_main.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/utils/cleaner_main.py' -> '/content/benchmarking-gnns/utils/cleaner_main.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/utils/cleaner_main_old.py' -> '/content/benchmarking-gnns/utils/cleaner_main_old.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/visualization' -> '/content/benchmarking-gnns/visualization'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/visualization/superpixels_visualization_cifar10.ipynb' -> '/content/benchmarking-gnns/visualization/superpixels_visualization_cifar10.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/visualization/visualizations_dataset_stats.ipynb' -> '/content/benchmarking-gnns/visualization/visualizations_dataset_stats.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/visualization/superpixels_visualization_mnist.ipynb' -> '/content/benchmarking-gnns/visualization/superpixels_visualization_mnist.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/docs' -> '/content/benchmarking-gnns/docs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/docs/07_leaderboards.md' -> '/content/benchmarking-gnns/docs/07_leaderboards.md'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/docs/02_download_datasets.md' -> '/content/benchmarking-gnns/docs/02_download_datasets.md'
# ...
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/graphtheoryprop.py' -> '/content/benchmarking-gnns/data/graphtheoryprop.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/script_download_molecules.sh' -> '/content/benchmarking-gnns/data/script_download_molecules.sh'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs.py' -> '/content/benchmarking-gnns/data/TUs.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/script_download_CSL.sh' -> '/content/benchmarking-gnns/data/script_download_CSL.sh'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/script_download_SBMs.sh' -> '/content/benchmarking-gnns/data/script_download_SBMs.sh'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/cycles.py' -> '/content/benchmarking-gnns/data/cycles.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs.py' -> '/content/benchmarking-gnns/data/SBMs.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/script_download_superpixels.sh' -> '/content/benchmarking-gnns/data/script_download_superpixels.sh'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/data.py' -> '/content/benchmarking-gnns/data/data.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/.DS_Store' -> '/content/benchmarking-gnns/data/.DS_Store'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/superpixels' -> '/content/benchmarking-gnns/data/superpixels'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/superpixels/prepare_superpixels_MNIST.ipynb' -> '/content/benchmarking-gnns/data/superpixels/prepare_superpixels_MNIST.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/superpixels/prepare_superpixels_CIFAR.ipynb' -> '/content/benchmarking-gnns/data/superpixels/prepare_superpixels_CIFAR.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/cycles' -> '/content/benchmarking-gnns/data/cycles'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/cycles/build_cycles.py' -> '/content/benchmarking-gnns/data/cycles/build_cycles.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/cycles/prepare_cycles.ipynb' -> '/content/benchmarking-gnns/data/cycles/prepare_cycles.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs' -> '/content/benchmarking-gnns/data/SBMs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/generate_SBM_PATTERN.ipynb' -> '/content/benchmarking-gnns/data/SBMs/generate_SBM_PATTERN.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/generate_SBM_CLUSTER.ipynb' -> '/content/benchmarking-gnns/data/SBMs/generate_SBM_CLUSTER.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/prepare_SBM_PATTERN.ipynb' -> '/content/benchmarking-gnns/data/SBMs/prepare_SBM_PATTERN.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/prepare_SBM_CLUSTER.ipynb' -> '/content/benchmarking-gnns/data/SBMs/prepare_SBM_CLUSTER.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/.DS_Store' -> '/content/benchmarking-gnns/data/SBMs/.DS_Store'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/SBM_CLUSTER.pkl' -> '/content/benchmarking-gnns/data/SBMs/SBM_CLUSTER.pkl'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/SBMs/SBM_PATTERN.pkl' -> '/content/benchmarking-gnns/data/SBMs/SBM_PATTERN.pkl'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/molecules' -> '/content/benchmarking-gnns/data/molecules'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/molecules/prepare_molecules.ipynb' -> '/content/benchmarking-gnns/data/molecules/prepare_molecules.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/molecules/test.index' -> '/content/benchmarking-gnns/data/molecules/test.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/molecules/val.index' -> '/content/benchmarking-gnns/data/molecules/val.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/molecules/train.index' -> '/content/benchmarking-gnns/data/molecules/train.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/molecules/prepare_molecules_ZINC_full.ipynb' -> '/content/benchmarking-gnns/data/molecules/prepare_molecules_ZINC_full.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/graphtheoryprop' -> '/content/benchmarking-gnns/data/graphtheoryprop'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/graphtheoryprop/prepare_graphtheoryprop.ipynb' -> '/content/benchmarking-gnns/data/graphtheoryprop/prepare_graphtheoryprop.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TSP' -> '/content/benchmarking-gnns/data/TSP'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TSP/prepare_TSP.ipynb' -> '/content/benchmarking-gnns/data/TSP/prepare_TSP.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TSP/generate_TSP.py' -> '/content/benchmarking-gnns/data/TSP/generate_TSP.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs' -> '/content/benchmarking-gnns/data/TUs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/DD_val.index' -> '/content/benchmarking-gnns/data/TUs/DD_val.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/DD_train.index' -> '/content/benchmarking-gnns/data/TUs/DD_train.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/README.md' -> '/content/benchmarking-gnns/data/TUs/README.md'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/ENZYMES_test.index' -> '/content/benchmarking-gnns/data/TUs/ENZYMES_test.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/PROTEINS_full_test.index' -> '/content/benchmarking-gnns/data/TUs/PROTEINS_full_test.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/ENZYMES_train.index' -> '/content/benchmarking-gnns/data/TUs/ENZYMES_train.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/COLLAB_test.index' -> '/content/benchmarking-gnns/data/TUs/COLLAB_test.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/DD_test.index' -> '/content/benchmarking-gnns/data/TUs/DD_test.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/COLLAB_val.index' -> '/content/benchmarking-gnns/data/TUs/COLLAB_val.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/PROTEINS_full_train.index' -> '/content/benchmarking-gnns/data/TUs/PROTEINS_full_train.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/COLLAB_train.index' -> '/content/benchmarking-gnns/data/TUs/COLLAB_train.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/PROTEINS_full_val.index' -> '/content/benchmarking-gnns/data/TUs/PROTEINS_full_val.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/TUs/ENZYMES_val.index' -> '/content/benchmarking-gnns/data/TUs/ENZYMES_val.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/CSL' -> '/content/benchmarking-gnns/data/CSL'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/CSL/CSL_train.index' -> '/content/benchmarking-gnns/data/CSL/CSL_train.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/CSL/CSL_test.index' -> '/content/benchmarking-gnns/data/CSL/CSL_test.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/CSL/CSL_val.index' -> '/content/benchmarking-gnns/data/CSL/CSL_val.index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__' -> '/content/benchmarking-gnns/data/__pycache__'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/superpixels.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/superpixels.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/TUs.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/TUs.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/molecules.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/molecules.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/COLLAB.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/COLLAB.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/SBMs.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/SBMs.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/TSP.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/TSP.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/data.cpython-38.pyc' -> '/content/benchmarking-gnns/data/__pycache__/data.cpython-38.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/data.cpython-37.pyc' -> '/content/benchmarking-gnns/data/__pycache__/data.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/__pycache__/SBMs.cpython-37.pyc' -> '/content/benchmarking-gnns/data/__pycache__/SBMs.cpython-37.pyc'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/.ipynb_checkpoints' -> '/content/benchmarking-gnns/data/.ipynb_checkpoints'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/.ipynb_checkpoints/script_download_SBMs-checkpoint.sh' -> '/content/benchmarking-gnns/data/.ipynb_checkpoints/script_download_SBMs-checkpoint.sh'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/.ipynb_checkpoints/SBMs-checkpoint.py' -> '/content/benchmarking-gnns/data/.ipynb_checkpoints/SBMs-checkpoint.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/data/.ipynb_checkpoints/data-checkpoint.py' -> '/content/benchmarking-gnns/data/.ipynb_checkpoints/data-checkpoint.py'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git' -> '/content/benchmarking-gnns/.git'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/description' -> '/content/benchmarking-gnns/.git/description'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/HEAD' -> '/content/benchmarking-gnns/.git/HEAD'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/index' -> '/content/benchmarking-gnns/.git/index'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/config' -> '/content/benchmarking-gnns/.git/config'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/packed-refs' -> '/content/benchmarking-gnns/.git/packed-refs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/.DS_Store' -> '/content/benchmarking-gnns/.git/.DS_Store'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/objects' -> '/content/benchmarking-gnns/.git/objects'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/objects/info' -> '/content/benchmarking-gnns/.git/objects/info'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/objects/pack' -> '/content/benchmarking-gnns/.git/objects/pack'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/objects/pack/pack-59b3af3b3e41adf7408ff8994559d6ac1b4a3a89.idx' -> '/content/benchmarking-gnns/.git/objects/pack/pack-59b3af3b3e41adf7408ff8994559d6ac1b4a3a89.idx'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/objects/pack/pack-59b3af3b3e41adf7408ff8994559d6ac1b4a3a89.pack' -> '/content/benchmarking-gnns/.git/objects/pack/pack-59b3af3b3e41adf7408ff8994559d6ac1b4a3a89.pack'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/info' -> '/content/benchmarking-gnns/.git/info'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/info/exclude' -> '/content/benchmarking-gnns/.git/info/exclude'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs' -> '/content/benchmarking-gnns/.git/logs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/HEAD' -> '/content/benchmarking-gnns/.git/logs/HEAD'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/refs' -> '/content/benchmarking-gnns/.git/logs/refs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/refs/heads' -> '/content/benchmarking-gnns/.git/logs/refs/heads'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/refs/heads/master-dgl-0.6' -> '/content/benchmarking-gnns/.git/logs/refs/heads/master-dgl-0.6'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/refs/remotes' -> '/content/benchmarking-gnns/.git/logs/refs/remotes'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/refs/remotes/origin' -> '/content/benchmarking-gnns/.git/logs/refs/remotes/origin'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/logs/refs/remotes/origin/HEAD' -> '/content/benchmarking-gnns/.git/logs/refs/remotes/origin/HEAD'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks' -> '/content/benchmarking-gnns/.git/hooks'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/update.sample' -> '/content/benchmarking-gnns/.git/hooks/update.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/pre-applypatch.sample' -> '/content/benchmarking-gnns/.git/hooks/pre-applypatch.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/pre-receive.sample' -> '/content/benchmarking-gnns/.git/hooks/pre-receive.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/fsmonitor-watchman.sample' -> '/content/benchmarking-gnns/.git/hooks/fsmonitor-watchman.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/pre-commit.sample' -> '/content/benchmarking-gnns/.git/hooks/pre-commit.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/pre-rebase.sample' -> '/content/benchmarking-gnns/.git/hooks/pre-rebase.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/post-update.sample' -> '/content/benchmarking-gnns/.git/hooks/post-update.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/applypatch-msg.sample' -> '/content/benchmarking-gnns/.git/hooks/applypatch-msg.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/commit-msg.sample' -> '/content/benchmarking-gnns/.git/hooks/commit-msg.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/prepare-commit-msg.sample' -> '/content/benchmarking-gnns/.git/hooks/prepare-commit-msg.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/hooks/pre-push.sample' -> '/content/benchmarking-gnns/.git/hooks/pre-push.sample'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs' -> '/content/benchmarking-gnns/.git/refs'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs/remotes' -> '/content/benchmarking-gnns/.git/refs/remotes'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs/remotes/origin' -> '/content/benchmarking-gnns/.git/refs/remotes/origin'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs/remotes/origin/HEAD' -> '/content/benchmarking-gnns/.git/refs/remotes/origin/HEAD'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs/heads' -> '/content/benchmarking-gnns/.git/refs/heads'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs/heads/master-dgl-0.6' -> '/content/benchmarking-gnns/.git/refs/heads/master-dgl-0.6'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/.git/refs/tags' -> '/content/benchmarking-gnns/.git/refs/tags'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_SBMs_node_classification.ipynb' -> '/content/benchmarking-gnns/main_SBMs_node_classification.ipynb'
# '/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns/main_SBMs_node_classification.py' -> '/content/benchmarking-gnns/main_SBMs_node_classification.py'

# %%
# %cd benchmarking-gnns
# Out:
# /content/benchmarking-gnns

# %%
# %cd /content/benchmarking-gnns/
# Out:
# /content/benchmarking-gnns

# %%
# !conda env create -f /content/benchmarking-gnns/environment_gpu.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# Downloading and Extracting Packages
# freetype-2.10.4      | 890 KB    | : 100% 1.0/1 [00:00<00:00,  5.01s/it]
# sqlite-3.33.0        | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.57it/s]
# future-0.18.2        | 714 KB    | : 100% 1.0/1 [00:00<00:00,  4.84it/s]
# tqdm-4.43.0          | 47 KB     | : 100% 1.0/1 [00:00<00:00,  7.03it/s]
# cytoolz-0.11.0       | 403 KB    | : 100% 1.0/1 [00:00<00:00,  7.47it/s]
# matplotlib-3.1.0     | 6 KB      | : 100% 1.0/1 [00:00<00:00,  8.28it/s]
# libcurl-7.78.0       | 335 KB    | : 100% 1.0/1 [00:00<00:00, 10.99it/s]
# wcwidth-0.2.5        | 33 KB     | : 100% 1.0/1 [00:00<00:00, 18.66it/s]
# attrs-21.2.0         | 44 KB     | : 100% 1.0/1 [00:00<00:00, 17.26it/s]
# entrypoints-0.3      | 8 KB      | : 100% 1.0/1 [00:00<00:00, 22.80it/s]
# packaging-21.0       | 35 KB     | : 100% 1.0/1 [00:00<00:00, 20.91it/s]
# absl-py-0.13.0       | 97 KB     | : 100% 1.0/1 [00:00<00:00, 12.19it/s]
# fontconfig-2.13.1    | 327 KB    | : 100% 1.0/1 [00:00<00:00,  9.59it/s]
# backcall-0.2.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 23.02it/s]
# cloudpickle-1.6.0    | 22 KB     | : 100% 1.0/1 [00:00<00:00, 22.04it/s]
# importlib-metadata-4 | 31 KB     | : 100% 1.0/1 [00:00<00:00, 19.86it/s]
# pygments-2.9.0       | 754 KB    | : 100% 1.0/1 [00:00<00:00,  4.79it/s]
# ptyprocess-0.7.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00, 23.44it/s]
# toolz-0.11.1         | 46 KB     | : 100% 1.0/1 [00:00<00:00, 17.18it/s]
# libpng-1.6.37        | 306 KB    | : 100% 1.0/1 [00:00<00:00, 10.59it/s]
# fsspec-2021.7.0      | 81 KB     | : 100% 1.0/1 [00:00<00:00, 17.47it/s]
# pyyaml-5.4.1         | 189 KB    | : 100% 1.0/1 [00:00<00:00, 10.54it/s]
# ipywidgets-7.5.1     | 101 KB    | : 100% 1.0/1 [00:00<00:00, 15.37it/s]
# retrying-1.3.3       | 11 KB     | : 100% 1.0/1 [00:00<00:00, 15.22it/s]
# jbig-2.1             | 43 KB     | : 100% 1.0/1 [00:00<00:00, 25.09it/s]
# pyqt-5.9.2           | 5.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.17s/it]
# pandoc-2.14.1        | 12.0 MB   | : 100% 1.0/1 [00:02<00:00,  1.75s/it]
# libtiff-4.3.0        | 668 KB    | : 100% 1.0/1 [00:00<00:00,  4.74it/s]
# libssh2-1.9.0        | 226 KB    | : 100% 1.0/1 [00:00<00:00, 10.08it/s]
# intel-openmp-2020.2  | 947 KB    | : 100% 1.0/1 [00:00<00:00,  5.06it/s]
# yaml-0.2.5           | 82 KB     | : 100% 1.0/1 [00:00<00:00, 19.62it/s]
# chardet-3.0.4        | 170 KB    | : 100% 1.0/1 [00:00<00:00, 13.67it/s]
# pyzmq-22.2.1         | 514 KB    | : 100% 1.0/1 [00:00<00:00,  6.83it/s]
# tensorboard-1.14.0   | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 19.05it/s]
# six-1.16.0           | 14 KB     | : 100% 1.0/1 [00:00<00:00, 20.45it/s]
# wheel-0.37.0         | 31 KB     | : 100% 1.0/1 [00:00<00:00,  8.81it/s]
# libgcc-ng-11.1.0     | 908 KB    | : 100% 1.0/1 [00:00<00:00,  6.23it/s]
# mkl-2019.4           | 204.1 MB  | : 100% 1.0/1 [00:33<00:00, 33.42s/it]
# zlib-1.2.11          | 106 KB    | : 100% 1.0/1 [00:00<00:00, 12.93it/s]
# webencodings-0.5.1   | 12 KB     | : 100% 1.0/1 [00:00<00:00, 21.74it/s]
# libev-4.33           | 104 KB    | : 100% 1.0/1 [00:00<00:00, 17.78it/s]
# libcblas-3.8.0       | 10 KB     | : 100% 1.0/1 [00:00<00:00,  8.56it/s]
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:00<00:00, 18.67it/s]
# parso-0.7.1          | 70 KB     | : 100% 1.0/1 [00:00<00:00, 12.58it/s]
# xorg-libxdmcp-1.1.3  | 19 KB     | : 100% 1.0/1 [00:00<00:00, 14.52it/s]
# zstd-1.5.0           | 490 KB    | : 100% 1.0/1 [00:00<00:00,  1.82it/s]
# mistune-0.8.4        | 54 KB     | : 100% 1.0/1 [00:00<00:00, 15.86it/s]
# krb5-1.19.2          | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
# hdf5-1.10.5          | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.28it/s]
# h5py-2.9.0           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  6.40s/it]
# libgomp-11.1.0       | 427 KB    | : 100% 1.0/1 [00:00<00:00,  7.87it/s]
# numpy-1.19.2         | 5.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.37s/it]
# joblib-1.0.1         | 206 KB    | : 100% 1.0/1 [00:00<00:00,  9.20it/s]
# openssl-1.1.1k       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# protobuf-3.17.2      | 347 KB    | : 100% 1.0/1 [00:00<00:00,  7.81it/s]
# pyrsistent-0.17.3    | 89 KB     | : 100% 1.0/1 [00:00<00:00, 11.42it/s]
# zipp-3.5.0           | 12 KB     | : 100% 1.0/1 [00:00<00:00, 22.65it/s]
# torchvision-0.7.0    | 11.0 MB   | : 100% 1.0/1 [00:02<00:00, 98.01s/it]
# partd-1.2.0          | 18 KB     | : 100% 1.0/1 [00:00<00:00, 16.77it/s]
# nbconvert-5.6.1      | 487 KB    | : 100% 1.0/1 [00:00<00:00,  6.61it/s]
# cycler-0.10.0        | 9 KB      | : 100% 1.0/1 [00:00<00:00, 24.89it/s]
# libblas-3.8.0        | 10 KB     | : 100% 1.0/1 [00:00<00:00,  8.02it/s]
# qt-5.9.7             | 85.9 MB   | : 100% 1.0/1 [00:14<00:00, 14.29s/it]
# jupyter-1.0.0        | 6 KB      | : 100% 1.0/1 [00:00<00:00, 20.75it/s]
# blas-2.14            | 10 KB     | : 100% 1.0/1 [00:00<00:00,  8.09it/s]
# bleach-4.0.0         | 111 KB    | : 100% 1.0/1 [00:00<00:00, 14.44it/s]
# gst-plugins-base-1.1 | 6.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.37it/s]
# locket-0.2.0         | 6 KB      | : 100% 1.0/1 [00:00<00:00, 24.49it/s]
# jupyter_console-6.0. | 19 KB     | : 100% 1.0/1 [00:00<00:00, 24.52it/s]
# cryptography-3.4.7   | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.18it/s]
# jpeg-9d              | 264 KB    | : 100% 1.0/1 [00:00<00:00, 10.13it/s]
# pcre-8.45            | 253 KB    | : 100% 1.0/1 [00:00<00:00, 11.82it/s]
# libuuid-2.32.1       | 28 KB     | : 100% 1.0/1 [00:00<00:00, 22.44it/s]
# cudnn-7.6.5.32       | 259.0 MB  | : 100% 1.0/1 [00:32<00:00, 32.95s/it]
# traitlets-5.0.5      | 81 KB     | : 100% 1.0/1 [00:00<00:00, 12.19it/s]
# scipy-1.3.0          | 18.8 MB   | : 100% 1.0/1 [00:04<00:00,  4.15s/it]
# pip-19.2.3           | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  7.86s/it]
# ncurses-6.2          | 985 KB    | : 100% 1.0/1 [00:00<00:00,  2.54it/s]
# terminado-0.10.1     | 26 KB     | : 100% 1.0/1 [00:00<00:00, 18.44it/s]
# notebook-6.0.0       | 6.0 MB    | : 100% 1.0/1 [00:01<00:00, 28.32s/it]
# olefile-0.46         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 22.55it/s]
# jedi-0.17.2          | 948 KB    | : 100% 1.0/1 [00:00<00:00,  2.68it/s]
# gettext-0.19.8.1     | 3.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
# dataclasses-0.8      | 7 KB      | : 100% 1.0/1 [00:00<00:00, 24.24it/s]
# tornado-6.1          | 646 KB    | : 100% 1.0/1 [00:00<00:00,  6.18it/s]
# python-3.7.4         | 36.5 MB   | : 100% 1.0/1 [00:06<00:00,  6.81s/it]
# dask-core-2021.7.2   | 757 KB    | : 100% 1.0/1 [00:00<00:00,  4.37it/s]
# certifi-2021.5.30    | 141 KB    | : 100% 1.0/1 [00:00<00:00, 15.80it/s]
# nbformat-5.1.3       | 47 KB     | : 100% 1.0/1 [00:00<00:00, 17.13it/s]
# qtconsole-5.1.1      | 89 KB     | : 100% 1.0/1 [00:00<00:00, 14.29it/s]
# libedit-3.1.20191231 | 121 KB    | : 100% 1.0/1 [00:00<00:00, 12.33it/s]
# dgl-cuda10.2-0.6.1   | 23.9 MB   | : 100% 1.0/1 [00:10<00:00, 10.38s/it]
# gstreamer-1.14.5     | 4.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.70it/s]
# libiconv-1.16        | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  4.84it/s]
# markupsafe-2.0.1     | 22 KB     | : 100% 1.0/1 [00:00<00:00, 24.64it/s]
# libprotobuf-3.17.2   | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.00it/s]
# zeromq-4.3.4         | 352 KB    | : 100% 1.0/1 [00:00<00:00,  9.78it/s]
# libffi-3.2.1         | 47 KB     | : 100% 1.0/1 [00:00<00:00, 20.83it/s]
# pywavelets-1.1.1     | 4.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
# cudatoolkit-10.2.89  | 449.7 MB  | : 100% 1.0/1 [00:55<00:00, 55.55s/it]
# dbus-1.13.6          | 602 KB    | : 100% 1.0/1 [00:00<00:00,  5.37it/s]
# jinja2-3.0.1         | 99 KB     | : 100% 1.0/1 [00:00<00:00, 17.07it/s]
# python-dateutil-2.8. | 219 KB    | : 100% 1.0/1 [00:00<00:00, 13.44it/s]
# werkzeug-2.0.1       | 219 KB    | : 100% 1.0/1 [00:00<00:00, 12.18it/s]
# pickleshare-0.7.5    | 9 KB      | : 100% 1.0/1 [00:00<00:00, 23.19it/s]
# kiwisolver-1.3.1     | 78 KB     | : 100% 1.0/1 [00:00<00:00, 19.84it/s]
# scikit-learn-0.21.2  | 6.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.19s/it]
# liblapacke-3.8.0     | 10 KB     | : 100% 1.0/1 [00:00<00:00, 18.77it/s]
# readline-7.0         | 391 KB    | : 100% 1.0/1 [00:00<00:00,  6.63it/s]
# lerc-2.2.1           | 213 KB    | : 100% 1.0/1 [00:00<00:00, 11.97it/s]
# pthread-stubs-0.4    | 5 KB      | : 100% 1.0/1 [00:00<00:00, 17.89it/s]
# libxml2-2.9.9        | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# imageio-2.9.0        | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
# cffi-1.14.4          | 224 KB    | : 100% 1.0/1 [00:00<00:00, 11.02it/s]
# xz-5.2.5             | 343 KB    | : 100% 1.0/1 [00:00<00:00,  9.35it/s]
# pexpect-4.8.0        | 47 KB     | : 100% 1.0/1 [00:00<00:00, 18.95it/s]
# pillow-6.1.0         | 630 KB    | : 100% 1.0/1 [00:00<00:00,  7.98s/it]
# defusedxml-0.7.1     | 23 KB     | : 100% 1.0/1 [00:00<00:00, 22.81it/s]
# jupyter_client-5.3.1 | 64 KB     | : 100% 1.0/1 [00:00<00:00, 12.30it/s]
# qtpy-1.9.0           | 34 KB     | : 100% 1.0/1 [00:00<00:00,  8.91it/s]
# libwebp-base-1.2.0   | 815 KB    | : 100% 1.0/1 [00:00<00:00,  5.75it/s]
# ipython_genutils-0.2 | 21 KB     | : 100% 1.0/1 [00:00<00:00, 23.54it/s]
# decorator-5.0.9      | 11 KB     | : 100% 1.0/1 [00:00<00:00, 20.39it/s]
# requests-2.22.0      | 84 KB     | : 100% 1.0/1 [00:00<00:00,  5.30it/s]
# _openmp_mutex-4.5    | 22 KB     | : 100% 1.0/1 [00:00<00:00, 19.67it/s]
# prompt_toolkit-2.0.1 | 221 KB    | : 100% 1.0/1 [00:00<00:00, 10.65it/s]
# ninja-1.10.2         | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# setuptools-49.6.0    | 947 KB    | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# libnghttp2-1.43.0    | 808 KB    | : 100% 1.0/1 [00:00<00:00,  6.28it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 23.76it/s]
# ca-certificates-2021 | 136 KB    | : 100% 1.0/1 [00:00<00:00, 17.60it/s]
# ipython-7.7.0        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  7.24s/it]
# jsonschema-3.2.0     | 45 KB     | : 100% 1.0/1 [00:00<00:00, 16.86it/s]
# scikit-image-0.15.0  | 28.4 MB   | : 100% 1.0/1 [00:03<00:00,  3.34s/it]
# icu-58.2             | 22.6 MB   | : 100% 1.0/1 [00:03<00:00,  5.33s/it]
# widgetsnbextension-3 | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# libdeflate-1.7       | 67 KB     | : 100% 1.0/1 [00:00<00:00, 19.58it/s]
# liblapack-3.8.0      | 10 KB     | : 100% 1.0/1 [00:00<00:00, 24.55it/s]
# prometheus_client-0. | 46 KB     | : 100% 1.0/1 [00:00<00:00, 15.73it/s]
# tk-8.6.10            | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.66it/s]
# tensorboardx-1.8     | 70 KB     | : 100% 1.0/1 [00:00<00:00,  1.77it/s]
# glib-2.66.1          | 3.5 MB    | : 100% 1.0/1 [00:01<00:00,  8.57s/it]
# typing_extensions-3. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 19.26it/s]
# matplotlib-base-3.1. | 6.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.82s/it]
# pandocfilters-1.4.2  | 9 KB      | : 100% 1.0/1 [00:00<00:00, 17.92it/s]
# libgfortran4-7.5.0   | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.72it/s]
# c-ares-1.17.2        | 109 KB    | : 100% 1.0/1 [00:00<00:00, 15.95it/s]
# idna-2.8             | 100 KB    | : 100% 1.0/1 [00:00<00:00, 17.62it/s]
# plotly-4.1.1         | 4.0 MB    | : 100% 1.0/1 [00:01<00:00, 11.92s/it]
# pytorch-1.6.0        | 537.7 MB  | : 100% 1.0/1 [01:21<00:00, 81.80s/it]
# expat-2.4.1          | 182 KB    | : 100% 1.0/1 [00:00<00:00, 10.14it/s]
# markdown-3.3.4       | 67 KB     | : 100% 1.0/1 [00:00<00:00, 17.28it/s]
# libstdcxx-ng-11.1.0  | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
# lz4-c-1.9.3          | 179 KB    | : 100% 1.0/1 [00:00<00:00, 13.38it/s]
# pycparser-2.20       | 94 KB     | : 100% 1.0/1 [00:00<00:00, 12.60it/s]
# backports-1.0        | 4 KB      | : 100% 1.0/1 [00:00<00:00, 14.12it/s]
# libsodium-1.0.18     | 366 KB    | : 100% 1.0/1 [00:00<00:00,  9.15it/s]
# xorg-libxau-1.0.9    | 13 KB     | : 100% 1.0/1 [00:00<00:00, 14.83it/s]
# pyparsing-2.4.7      | 60 KB     | : 100% 1.0/1 [00:00<00:00, 19.76it/s]
# brotlipy-0.7.0       | 341 KB    | : 100% 1.0/1 [00:00<00:00, 10.60it/s]
# ipykernel-5.1.2      | 159 KB    | : 100% 1.0/1 [00:00<00:00,  5.79it/s]
# testpath-0.5.0       | 86 KB     | : 100% 1.0/1 [00:00<00:00, 15.67it/s]
# networkx-2.3         | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.67it/s]
# pyopenssl-20.0.1     | 48 KB     | : 100% 1.0/1 [00:00<00:00, 19.40it/s]
# sip-4.19.8           | 290 KB    | : 100% 1.0/1 [00:00<00:00, 11.39it/s]
# libxcb-1.13          | 395 KB    | : 100% 1.0/1 [00:00<00:00,  6.05it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 19.58it/s]
# send2trash-1.8.0     | 17 KB     | : 100% 1.0/1 [00:00<00:00, 13.09it/s]
# jupyter_core-4.5.0   | 44 KB     | : 100% 1.0/1 [00:00<00:00, 16.33it/s]
# backports.functools_ | 9 KB      | : 100% 1.0/1 [00:00<00:00, 19.91it/s]
# urllib3-1.25.11      | 93 KB     | : 100% 1.0/1 [00:00<00:00, 16.79it/s]
# done
# done
# - b'By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html\n'
# \ b'By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA -\n  https://docs.nvidia.com/deeplearning/cudnn/sla/index.html\n'
# - b'Enabling notebook extension jupyter-js-widgets/extension...\nPaths used for configuration of notebook: \n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.d/plotlywidget.json\n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json\n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.json\nPaths used for configuration of notebook: \n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.d/plotlywidget.json\n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json\n      - Validating: \x1bOK\x1b\nPaths used for configuration of notebook: \n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.d/plotlywidget.json\n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.d/widgetsnbextension.json\n    \t/usr/local/envs/benchmark_gnn/etc/jupyter/nbconfig/notebook.json\n'
# done
# Ran pip subprocess with arguments:
# ['/usr/local/envs/benchmark_gnn/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt']
# Pip subprocess output:
# Collecting tensorflow-gpu==2.1.0 (from -r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0c/e8/56ecca076108302a0bc34d509dc891086455ac31895843403ef0a71d0497/tensorflow_gpu-2.1.0-cp37-cp37m-manylinux2010_x86_64.whl (421.8MB)
# Collecting tensorflow-estimator==2.1.0 (from -r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
# Collecting tensorboard==2.1.1 (from -r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
# Collecting ogb==1.2.2 (from -r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/38/e8/ae50429b9f39a056738b47e3144602b2ca00a55f92df6d1808d5605ccf91/ogb-1.2.2-py3-none-any.whl (45kB)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1)) (0.13.0)
# Collecting wrapt>=1.11.1 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/82/f7/e43cefbe88c5fd371f4cf0cf5eb3feccd07515af9fd6cf7dbf1d1793a797/wrapt-1.12.1.tar.gz
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1)) (0.37.0)
# Collecting astor>=0.6.0 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Collecting gast==0.2.2 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting opt-einsum>=2.3.2 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl (65kB)
# Collecting keras-applications>=1.0.8 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
# Collecting termcolor>=1.1.0 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting keras-preprocessing>=1.1.0 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
# Collecting google-pasta>=0.1.6 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl (57kB)
# Collecting grpcio>=1.8.6 (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/66/61/680d8a5a146e33ac463e0fa800ee37c6becbeee4aa02522fa6632dca8831/grpcio-1.39.0-cp37-cp37m-manylinux2010_x86_64.whl (4.1MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1)) (1.19.2)
# Collecting scipy==1.4.1; python_version >= "3" (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/dd/82/c1fe128f3526b128cfd185580ba40d01371c5d299fcf7f77968e22dfcc2e/scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1MB)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1)) (3.17.2)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (3.3.4)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (49.6.0.post20210108)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (2.0.1)
# Collecting google-auth<2,>=1.6.3 (from tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/35/bb/694d851e2c0776a422d43d579b82b7cc065da248d557f37595563824b1c9/google_auth-1.34.0-py2.py3-none-any.whl (152kB)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (2.22.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/45/d9/df4019fc28b3aed8218e1bfca38158b90b70a3583c15f568ca669564dc24/google_auth_oauthlib-0.4.5-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: tqdm>=4.29.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (4.43.0)
# Requirement already satisfied, skipping upgrade: torch>=1.2.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (1.6.0)
# Collecting outdated>=0.2.0 (from ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/fd/f6/95588d496e518355c33b389222c99069b1c6f2c046be64f400072fdc7cda/outdated-0.2.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: urllib3>=1.24.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (1.25.11)
# Collecting pandas>=0.24.0 (from ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/12/01/360d7f444f910ae16496c07e3f003cb8c641b4ca6c033408a4469a904df3/pandas-1.3.1.tar.gz (4.7MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.0 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (0.21.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (4.6.3)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/bf/28/c4f5796c67ad06bb91d98d543a5e01805c1ff065e08871f78e52d2a331ad/cachetools-4.2.2-py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2,>=1.6.3->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6" (from google-auth<2,>=1.6.3->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/e9/93/0c0f002031f18b53af7a6166103c02b9c0667be528944137cc954ec921b3/rsa-4.7.2-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (2021.5.30)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (2.8)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: future in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from torch>=1.2.0->ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (0.18.2)
# Collecting littleutils (from outdated>=0.2.0->ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/4e/b1/bb4e06f010947d67349f863b6a2ad71577f85590180a935f60543f622652/littleutils-0.2.2.tar.gz
# Collecting pytz>=2017.3 (from pandas>=0.24.0->ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/70/94/784178ca5dd892a98f113cdd923372024dc04b8d40abe77ca76b5fb90ca6/pytz-2021.1-py2.py3-none-any.whl (510kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from pandas>=0.24.0->ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (2.8.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from scikit-learn>=0.20.0->ogb==1.2.2->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/envs/benchmark_gnn/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3)) (3.10.0.0)
# Collecting pyasn1<0.5.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.1.1->-r /content/benchmarking-gnns/condaenv.y5bxp0_a.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/e8/5d/9dd1c29e5a786525f6342f6c1d812ed2e37edc653ad297048c1668988053/oauthlib-3.1.1-py2.py3-none-any.whl (146kB)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (PEP 517): started
#   Building wheel for pandas (PEP 517): finished with status 'done'
#   Created wheel for pandas: filename=pandas-1.3.1-cp37-cp37m-linux_x86_64.whl size=30233658 sha256=52ff2d48304ffbdae1af3c54d800dca905d4e63ec962281f06d141b45a3c5f3e
#   Stored in directory: /root/.cache/pip/wheels/b8/5a/7d/71db201d3a50882d1675985fdc6493f7e6e4546457f3ac5a34
# Successfully built pandas
# Building wheels for collected packages: wrapt, gast, termcolor, littleutils
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=70957 sha256=05ee21c1f9fe208e8313315092ce5d180aa38a7d585aefda4d9389554bd2087e
#   Stored in directory: /root/.cache/pip/wheels/b1/c2/ed/d62208260edbd3fa7156545c00ef966f45f2063d0a84f8208a
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7541 sha256=1494d0ba4c83803eb2dcb18400aec3c61a5daa40051ba4895602bb5b5cd365f6
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp37-none-any.whl size=4833 sha256=21d5fba3c32ca3df53be969c37d38c0fb6023232409fd3889ec21c8956587a94
#   Stored in directory: /root/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for littleutils (setup.py): started
#   Building wheel for littleutils (setup.py): finished with status 'done'
#   Created wheel for littleutils: filename=littleutils-0.2.2-cp37-none-any.whl size=7050 sha256=0c9e9c6abfd616998e1cc084e9a47e58e62927dc8079d8f84a06ed4a05356277
#   Stored in directory: /root/.cache/pip/wheels/53/16/9f/ac67d15c40243754fd73f620e1b9b6dedc20492ecc19a2bae1
# Successfully built wrapt gast termcolor littleutils
# Installing collected packages: wrapt, astor, gast, opt-einsum, keras-applications, termcolor, tensorflow-estimator, keras-preprocessing, google-pasta, grpcio, scipy, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow-gpu, littleutils, outdated, pytz, pandas, ogb
#   Found existing installation: scipy 1.3.0
#     Uninstalling scipy-1.3.0:
#       Successfully uninstalled scipy-1.3.0
#   Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
# Successfully installed astor-0.8.1 cachetools-4.2.2 gast-0.2.2 google-auth-1.34.0 google-auth-oauthlib-0.4.5 google-pasta-0.2.0 grpcio-1.39.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 littleutils-0.2.2 oauthlib-3.1.1 ogb-1.2.2 opt-einsum-3.3.0 outdated-0.2.1 pandas-1.3.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2021.1 requests-oauthlib-1.3.0 rsa-4.7.2 scipy-1.4.1 tensorboard-2.1.1 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0 termcolor-1.1.0 wrapt-1.12.1
#
# #
# # To activate this environment, use
# #
# #     $ conda activate benchmark_gnn
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda activate benchmark_gnn
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %% [markdown]
# ## Main Driver Notebook for Training Graph NNs on SBM Datasets

# %% [markdown]
# ### MODELS
# - GatedGCN
# - GCN
# - GAT
# - GraphSage
# - MLP
# - GIN
# - MoNet
# - RingGNN
# - 3WLGNN
#
# ### DATASET
# - SBM_CLUSTER
# - SBM_PATTERN
#
# ### TASK
# - Node Classification

# %%
#!pip install tensorboardX

# %%
# !pip install dgl-cu101
#!pip install tensorboardX
# !pip install pytorch
#!pip install dgl
# !pip install tensorboardX
# Out:
# Collecting dgl-cu101
#   Downloading dgl_cu101-0.6.1-cp37-cp37m-manylinux1_x86_64.whl (36.2 MB)
#      |████████████████████████████████| 36.2 MB 78 kB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/site-packages (from dgl-cu101) (1.4.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/site-packages (from dgl-cu101) (2.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/site-packages (from dgl-cu101) (1.18.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/site-packages (from dgl-cu101) (2.22.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/site-packages (from networkx>=2.1->dgl-cu101) (4.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->dgl-cu101) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->dgl-cu101) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->dgl-cu101) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->dgl-cu101) (2.8)
# Installing collected packages: dgl-cu101
# Successfully installed dgl-cu101-0.6.1
# Collecting pytorch
#   Downloading pytorch-1.0.2.tar.gz (689 bytes)
# Building wheels for collected packages: pytorch
#   Building wheel for pytorch (setup.py) ... error
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# Installing collected packages: pytorch
#     Running setup.py install for pytorch ... error
# ERROR: Command errored out with exit status 1: /usr/local/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x5evizgi/pytorch/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x5evizgi/pytorch/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-8maae4j6/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7m/pytorch Check the logs for full command output.
# Collecting tensorboardX
#   Downloading tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 7.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from tensorboardX) (1.18.1)
# Collecting protobuf>=3.8.0
#   Downloading protobuf-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 40.9 MB/s
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/site-packages (from protobuf>=3.8.0->tensorboardX) (1.14.0)
# Installing collected packages: protobuf, tensorboardX
# Successfully installed protobuf-3.17.3 tensorboardX-2.4

# %%
import dgl
import numpy as np
import os
import socket
import time
import random
import glob
import argparse, json
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torch.utils.data import DataLoader

from tensorboardX import SummaryWriter
from tqdm import tqdm

class DotDict(dict):
    def __init__(self, **kwds):
        self.update(kwds)
        self.__dict__ = self
# Out:
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Using backend: pytorch

# %%
#import dgl

# %%
# """
#     AUTORELOAD IPYTHON EXTENSION FOR RELOADING IMPORTED MODULES
# """

def in_ipynb():
    try:
        cfg = get_ipython().config 
        return True
    except NameError:
        return False
    
notebook_mode = in_ipynb()
print(notebook_mode)

if notebook_mode == True:
    # %load_ext autoreload
    # %autoreload 2
# Out:
# True

# %%
"""
    IMPORTING CUSTOM MODULES/METHODS
"""

from nets.SBMs_node_classification.load_net import gnn_model # import GNNs
from data.data import LoadData # import dataset

# %%
"""
    GPU Setup
"""
def gpu_setup(use_gpu, gpu_id):
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
    os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)  

    if torch.cuda.is_available() and use_gpu:
        print('cuda available with GPU:',torch.cuda.get_device_name(0))
        device = torch.device("cuda")
    else:
        print('cuda not available')
        device = torch.device("cpu")
    return device


# select GPU or CPU
use_gpu = True; gpu_id = 0; device = None # default GPU
#use_gpu = False; gpu_id = -1; device = None # CPU

# %%
# """
#     USER CONTROLS
# """
if notebook_mode == True:
    
    #MODEL_NAME = '3WLGNN'
    #MODEL_NAME = 'RingGNN'
    #MODEL_NAME = 'GatedGCN'
    #MODEL_NAME = 'GCN'
    MODEL_NAME = 'GAT'
    #MODEL_NAME = 'GraphSage'
    #MODEL_NAME = 'MLP'
    #MODEL_NAME = 'GIN'
    #MODEL_NAME = 'MoNet'
    

    #DATASET_NAME = 'SBM_CLUSTER'
    DATASET_NAME = 'SBM_PATTERN'

    out_dir = 'out/SBMs_node_classification/'
    root_log_dir = out_dir + 'logs/' + MODEL_NAME + "_" + DATASET_NAME + "_" + time.strftime('%Hh%Mm%Ss_on_%b_%d_%Y')
    root_ckpt_dir = out_dir + 'checkpoints/' + MODEL_NAME + "_" + DATASET_NAME + "_" + time.strftime('%Hh%Mm%Ss_on_%b_%d_%Y')

    dataset = LoadData(DATASET_NAME)
    trainset, valset, testset = dataset.train, dataset.val, dataset.test
# Out:
# [I] Loading dataset SBM_PATTERN...
# train, test, val sizes : 10000 2000 2000
# [I] Finished loading.
# [I] Data load time: 55.9125s

# %%
#MODEL_NAME = 'RingGNN'
#MODEL_NAME = 'GatedGCN'
#MODEL_NAME = 'GCN'
MODEL_NAME = 'GAT'
#MODEL_NAME = 'GraphSage'
#MODEL_NAME = 'MLP'
#MODEL_NAME = 'DiffPool'
#MODEL_NAME = 'GIN'
#MODEL_NAME = 'MoNet'

# %%
# """
#     PARAMETERS
# """
if notebook_mode == True:

    n_heads = -1
    edge_feat = False
    pseudo_dim_MoNet = -1
    kernel = -1
    gnn_per_block = -1
    embedding_dim = -1
    pool_ratio = -1
    n_mlp_GIN = -1
    gated = False
    self_loop = False
    #self_loop = True
    max_time = 12
    pos_enc = True
    #pos_enc = False
    pos_enc_dim = 10
    

    if MODEL_NAME == 'GatedGCN':
        seed=41; epochs=1000; batch_size=5; init_lr=5e-5; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; hidden_dim=300; out_dim=hidden_dim; dropout=0.0; readout='mean'

    if MODEL_NAME == 'GCN':
        seed=41; epochs=1000; batch_size=5; init_lr=5e-5; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; hidden_dim=146; out_dim=hidden_dim; dropout=0.0; readout='mean'

    if MODEL_NAME == 'GAT':
        seed=41; epochs=120; batch_size=50; init_lr=5e-5; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; n_heads=8; hidden_dim=19; out_dim=n_heads*hidden_dim; dropout=0.0; readout='mean'
        print('True hidden dim:',out_dim)

    if MODEL_NAME == 'GraphSage':
        seed=41; epochs=1000; batch_size=50; init_lr=5e-5; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; hidden_dim=108; out_dim=hidden_dim; dropout=0.0; readout='mean'

    if MODEL_NAME == 'MLP':
        seed=41; epochs=1000; batch_size=50; init_lr=5e-4; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        gated=False; # MEAN
        L=4; hidden_dim=150; out_dim=hidden_dim; dropout=0.0; readout='mean'
        gated=True; # GATED
        L=4; hidden_dim=135; out_dim=hidden_dim; dropout=0.0; readout='mean'
        
    if MODEL_NAME == 'DiffPool':
        seed=41; epochs=1000; batch_size=50; init_lr=5e-4; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; hidden_dim=32; out_dim=hidden_dim; dropout=0.0; readout='mean'
        n_heads=8; gnn_per_block=3; embedding_dim=32; batch_size=128; pool_ratio=0.15

    if MODEL_NAME == 'GIN':
        seed=41; epochs=1000; batch_size=50; init_lr=5e-4; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; hidden_dim=110; out_dim=hidden_dim; dropout=0.0; readout='mean'
        n_mlp_GIN = 2; learn_eps_GIN=True; neighbor_aggr_GIN='sum'

    if MODEL_NAME == 'MoNet':
        seed=41; epochs=1000; batch_size=50; init_lr=5e-4; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=4; hidden_dim=70; out_dim=hidden_dim; dropout=0.0; readout='mean'
        pseudo_dim_MoNet=2; kernel=3;
        print('MoNet Selected')
        
    if MODEL_NAME == 'RingGNN':
        seed=41; epochs=1000; batch_size=1; init_lr=5e-5; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        #L=4; hidden_dim=145; out_dim=hidden_dim; dropout=0.0; readout='mean'
        L=4; hidden_dim=25; out_dim=hidden_dim; dropout=0.0
        
    if MODEL_NAME == '3WLGNN':
        seed=41; epochs=1000; batch_size=1; init_lr=5e-5; lr_reduce_factor=0.5; lr_schedule_patience=25; min_lr = 1e-6; weight_decay=0
        L=3; hidden_dim=82; out_dim=hidden_dim; dropout=0.0
      

        
    # generic new_params
    net_params = {}
    net_params['device'] = device
    net_params['in_dim'] = torch.unique(trainset[0][0].ndata['feat'],dim=0).size(0) # node_dim (feat is an integer)
    net_params['hidden_dim'] = hidden_dim
    net_params['out_dim'] = out_dim
    num_classes = torch.unique(trainset[0][1],dim=0).size(0)
    net_params['n_classes'] = num_classes
    net_params['L'] = L  # min L should be 2
    net_params['readout'] = "mean"
    net_params['layer_norm'] = True
    net_params['batch_norm'] = True
    net_params['in_feat_dropout'] = 0.0
    net_params['dropout'] = 0.0
    net_params['residual'] = True
    net_params['edge_feat'] = edge_feat
    net_params['self_loop'] = self_loop
    
    # for MLPNet 
    net_params['gated'] = gated  
    
    # for GAT
    net_params['n_heads'] = n_heads 
    
    # for graphsage
    net_params['sage_aggregator'] = 'meanpool' 

    # specific for GIN
    net_params['n_mlp_GIN'] = n_mlp_GIN
    net_params['learn_eps_GIN'] = True
    net_params['neighbor_aggr_GIN'] = 'sum'
    
    # specific for MoNet
    net_params['pseudo_dim_MoNet'] = pseudo_dim_MoNet
    net_params['kernel'] = kernel
    
    # specific for RingGNN
    net_params['radius'] = 2
    num_nodes = [dataset.train[i][0].number_of_nodes() for i in range(len(dataset.train))]
    net_params['avg_node_num'] = int(np.ceil(np.mean(num_nodes)))
    
    # specific for 3WLGNN
    net_params['depth_of_mlp'] = 2
    
    # specific for pos_enc_dim
    net_params['pos_enc'] = pos_enc
    net_params['pos_enc_dim'] = pos_enc_dim
# Out:
# True hidden dim: 152

# %%
"""
    VIEWING MODEL CONFIG AND PARAMS
"""
def view_model_param(MODEL_NAME, net_params):
    model = gnn_model(MODEL_NAME, net_params)
    total_param = 0
    print("MODEL DETAILS:\n")
    #print(model)
    for param in model.parameters():
        # print(param.data.size())
        total_param += np.prod(list(param.data.size()))
    print('MODEL/Total parameters:', MODEL_NAME, total_param)
    return total_param


if notebook_mode == True:
    view_model_param(MODEL_NAME, net_params)
# Out:
# MODEL DETAILS:
#
# MODEL/Total parameters: GAT 110544

# %%
"""
    TRAINING CODE
"""

def train_val_pipeline(MODEL_NAME, dataset, params, net_params, dirs):
    
    start0 = time.time()
    per_epoch_time = []
    
    DATASET_NAME = dataset.name
    print(MODEL_NAME, 'Selected')
    
    if MODEL_NAME in ['GCN', 'GAT']:
        if net_params['self_loop']:
            print("[!] Adding graph self-loops for GCN/GAT models (central node trick).")
            dataset._add_self_loops()
    
    if MODEL_NAME in ['GatedGCN']:
        if net_params['pos_enc']:
            print("[!] Adding graph positional encoding.")
            dataset._add_positional_encodings(net_params['pos_enc_dim'])
            print('Time PE:',time.time()-start0)
        
    trainset, valset, testset = dataset.train, dataset.val, dataset.test
        
    root_log_dir, root_ckpt_dir, write_file_name, write_config_file = dirs
    device = net_params['device']
    
    # Write network and optimization hyper-parameters in folder config/
    with open(write_config_file + '.txt', 'w') as f:
        f.write("""Dataset: {},\nModel: {}\n\nparams={}\n\nnet_params={}\n\n\nTotal Parameters: {}\n\n"""\
                .format(DATASET_NAME, MODEL_NAME, params, net_params, net_params['total_param']))
        
    log_dir = os.path.join(root_log_dir, "RUN_" + str(0))
    writer = SummaryWriter(log_dir=log_dir)

    # setting seeds
    random.seed(params['seed'])
    np.random.seed(params['seed'])
    torch.manual_seed(params['seed'])
    if device.type == 'cuda':
        torch.cuda.manual_seed(params['seed'])
    
    print("Training Graphs: ", len(trainset))
    print("Validation Graphs: ", len(valset))
    print("Test Graphs: ", len(testset))
    print("Number of Classes: ", net_params['n_classes'])

    model = gnn_model(MODEL_NAME, net_params)
    model = model.to(device)

    optimizer = optim.Adam(model.parameters(), lr=params['init_lr'], weight_decay=params['weight_decay'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                     factor=params['lr_reduce_factor'],
                                                     patience=params['lr_schedule_patience'],
                                                     verbose=True)
    
    epoch_train_losses, epoch_val_losses = [], []
    epoch_train_accs, epoch_val_accs = [], [] 
    
    if MODEL_NAME in ['RingGNN', '3WLGNN']:
        # import train functions specific for WL-GNNs
        from train.train_SBMs_node_classification import train_epoch_dense as train_epoch, evaluate_network_dense as evaluate_network
        
        train_loader = DataLoader(trainset, shuffle=True, collate_fn=dataset.collate_dense_gnn)
        val_loader = DataLoader(valset, shuffle=False, collate_fn=dataset.collate_dense_gnn)
        test_loader = DataLoader(testset, shuffle=False, collate_fn=dataset.collate_dense_gnn)
        
    else:
        # import train functions for all other GCNs
        from train.train_SBMs_node_classification import train_epoch_sparse as train_epoch, evaluate_network_sparse as evaluate_network # import train functions
        
        train_loader = DataLoader(trainset, batch_size=params['batch_size'], shuffle=True, collate_fn=dataset.collate)
        val_loader = DataLoader(valset, batch_size=params['batch_size'], shuffle=False, collate_fn=dataset.collate)
        test_loader = DataLoader(testset, batch_size=params['batch_size'], shuffle=False, collate_fn=dataset.collate)
        
    # At any point you can hit Ctrl + C to break out of training early.
    try:
        with tqdm(range(params['epochs'])) as t:
            for epoch in t:

                t.set_description('Epoch %d' % epoch)

                start = time.time()

                if MODEL_NAME in ['RingGNN', '3WLGNN']: # since different batch training function for dense GNNs
                    epoch_train_loss, epoch_train_acc, optimizer = train_epoch(model, optimizer, device, train_loader, epoch, params['batch_size'])
                else:   # for all other models common train function
                    epoch_train_loss, epoch_train_acc, optimizer = train_epoch(model, optimizer, device, train_loader, epoch)
                    
                epoch_val_loss, epoch_val_acc = evaluate_network(model, device, val_loader, epoch)
                _, epoch_test_acc = evaluate_network(model, device, test_loader, epoch)        
                
                epoch_train_losses.append(epoch_train_loss)
                epoch_val_losses.append(epoch_val_loss)
                epoch_train_accs.append(epoch_train_acc)
                epoch_val_accs.append(epoch_val_acc)

                writer.add_scalar('train/_loss', epoch_train_loss, epoch)
                writer.add_scalar('val/_loss', epoch_val_loss, epoch)
                writer.add_scalar('train/_acc', epoch_train_acc, epoch)
                writer.add_scalar('val/_acc', epoch_val_acc, epoch)
                writer.add_scalar('test/_acc', epoch_test_acc, epoch)
                writer.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], epoch)

                t.set_postfix(time=time.time()-start, lr=optimizer.param_groups[0]['lr'],
                              train_loss=epoch_train_loss, val_loss=epoch_val_loss,
                              train_acc=epoch_train_acc, val_acc=epoch_val_acc,
                              test_acc=epoch_test_acc)

                per_epoch_time.append(time.time()-start)

                # Saving checkpoint
                ckpt_dir = os.path.join(root_ckpt_dir, "RUN_")
                if not os.path.exists(ckpt_dir):
                    os.makedirs(ckpt_dir)
                torch.save(model.state_dict(), '{}.pkl'.format(ckpt_dir + "/epoch_" + str(epoch)))

                files = glob.glob(ckpt_dir + '/*.pkl')
                for file in files:
                    epoch_nb = file.split('_')[-1]
                    epoch_nb = int(epoch_nb.split('.')[0])
                    if epoch_nb < epoch-1:
                        os.remove(file)

                scheduler.step(epoch_val_loss)

                if optimizer.param_groups[0]['lr'] < params['min_lr']:
                    print("\n!! LR SMALLER OR EQUAL TO MIN LR THRESHOLD.")
                    break
                    
                # Stop training after params['max_time'] hours
                if time.time()-start0 > params['max_time']*3600:
                    print('-' * 89)
                    print("Max_time for training elapsed {:.2f} hours, so stopping".format(params['max_time']))
                    break
    
    except KeyboardInterrupt:
        print('-' * 89)
        print('Exiting from training early because of KeyboardInterrupt')
    
    
    _, test_acc = evaluate_network(model, device, test_loader, epoch)
    _, train_acc = evaluate_network(model, device, train_loader, epoch)
    print("Test Accuracy: {:.4f}".format(test_acc))
    print("Train Accuracy: {:.4f}".format(train_acc))
    print("Convergence Time (Epochs): {:.4f}".format(epoch))
    print("TOTAL TIME TAKEN: {:.4f}s".format(time.time()-start0))
    print("AVG TIME PER EPOCH: {:.4f}s".format(np.mean(per_epoch_time)))

    writer.close()

    """
        Write the results in out_dir/results folder
    """
    with open(write_file_name + '.txt', 'w') as f:
        f.write("""Dataset: {},\nModel: {}\n\nparams={}\n\nnet_params={}\n\n{}\n\nTotal Parameters: {}\n\n
    FINAL RESULTS\nTEST ACCURACY: {:.4f}\nTRAIN ACCURACY: {:.4f}\n\n
    Convergence Time (Epochs): {:.4f}\nTotal Time Taken: {:.4f} hrs\nAverage Time Per Epoch: {:.4f} s\n\n\n"""\
          .format(DATASET_NAME, MODEL_NAME, params, net_params, model, net_params['total_param'],
                  test_acc, train_acc, epoch, (time.time()-start0)/3600, np.mean(per_epoch_time)))

# %%
# !pip install nbconvert
import nbconvert
# Out:
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/site-packages (5.6.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/site-packages (from nbconvert) (0.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/site-packages (from nbconvert) (3.1.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/site-packages (from nbconvert) (2.5.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/site-packages (from nbconvert) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/site-packages (from nbconvert) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/site-packages (from nbconvert) (1.4.2)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/lib/python3.7/site-packages (from nbconvert) (5.0.4)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.7/site-packages (from nbconvert) (2.11.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/site-packages (from nbconvert) (0.4.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/site-packages (from nbconvert) (4.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/site-packages (from nbconvert) (4.3.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from bleach->nbconvert) (1.14.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/site-packages (from bleach->nbconvert) (0.5.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert) (1.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/site-packages (from traitlets>=4.2->nbconvert) (4.4.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (0.15.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (45.2.0.post20200210)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (2.2.0)

# %%
def main(notebook_mode=False,config=None):
    
    """
        USER CONTROLS
    """
    
    # terminal mode
    if notebook_mode==False:
        
        parser = argparse.ArgumentParser()
        parser.add_argument('--config', help="Please give a config.json file with training/model/data/param details")
        parser.add_argument('--gpu_id', help="Please give a value for gpu id")
        parser.add_argument('--model', help="Please give a value for model name")
        parser.add_argument('--dataset', help="Please give a value for dataset name")
        parser.add_argument('--out_dir', help="Please give a value for out_dir")
        parser.add_argument('--seed', help="Please give a value for seed")
        parser.add_argument('--epochs', help="Please give a value for epochs")
        parser.add_argument('--batch_size', help="Please give a value for batch_size")
        parser.add_argument('--init_lr', help="Please give a value for init_lr")
        parser.add_argument('--lr_reduce_factor', help="Please give a value for lr_reduce_factor")
        parser.add_argument('--lr_schedule_patience', help="Please give a value for lr_schedule_patience")
        parser.add_argument('--min_lr', help="Please give a value for min_lr")
        parser.add_argument('--weight_decay', help="Please give a value for weight_decay")
        parser.add_argument('--print_epoch_interval', help="Please give a value for print_epoch_interval")    
        parser.add_argument('--L', help="Please give a value for L")
        parser.add_argument('--hidden_dim', help="Please give a value for hidden_dim")
        parser.add_argument('--out_dim', help="Please give a value for out_dim")
        parser.add_argument('--residual', help="Please give a value for residual")
        parser.add_argument('--edge_feat', help="Please give a value for edge_feat")
        parser.add_argument('--readout', help="Please give a value for readout")
        parser.add_argument('--kernel', help="Please give a value for kernel")
        parser.add_argument('--n_heads', help="Please give a value for n_heads")
        parser.add_argument('--gated', help="Please give a value for gated")
        parser.add_argument('--in_feat_dropout', help="Please give a value for in_feat_dropout")
        parser.add_argument('--dropout', help="Please give a value for dropout")
        parser.add_argument('--layer_norm', help="Please give a value for layer_norm")
        parser.add_argument('--batch_norm', help="Please give a value for batch_norm")
        parser.add_argument('--sage_aggregator', help="Please give a value for sage_aggregator")
        parser.add_argument('--data_mode', help="Please give a value for data_mode")
        parser.add_argument('--num_pool', help="Please give a value for num_pool")
        parser.add_argument('--gnn_per_block', help="Please give a value for gnn_per_block")
        parser.add_argument('--embedding_dim', help="Please give a value for embedding_dim")
        parser.add_argument('--pool_ratio', help="Please give a value for pool_ratio")
        parser.add_argument('--linkpred', help="Please give a value for linkpred")
        parser.add_argument('--cat', help="Please give a value for cat")
        parser.add_argument('--self_loop', help="Please give a value for self_loop")
        parser.add_argument('--max_time', help="Please give a value for max_time")
        parser.add_argument('--pos_enc_dim', help="Please give a value for pos_enc_dim")
        parser.add_argument('--pos_enc', help="Please give a value for pos_enc")
        args = parser.parse_args()
        with open(args.config) as f:
            config = json.load(f)
            

        # device
        if args.gpu_id is not None:
            config['gpu']['id'] = int(args.gpu_id)
            config['gpu']['use'] = True
        device = gpu_setup(config['gpu']['use'], config['gpu']['id'])

        # model, dataset, out_dir
        if args.model is not None:
            MODEL_NAME = args.model
        else:
            MODEL_NAME = config['model']
        if args.dataset is not None:
            DATASET_NAME = args.dataset
        else:
            DATASET_NAME = config['dataset']
        dataset = LoadData(DATASET_NAME)
        if args.out_dir is not None:
            out_dir = args.out_dir
        else:
            out_dir = config['out_dir']

        # parameters
        params = config['params']
        if args.seed is not None:
            params['seed'] = int(args.seed)
        if args.epochs is not None:
            params['epochs'] = int(args.epochs)
        if args.batch_size is not None:
            params['batch_size'] = int(args.batch_size)
        if args.init_lr is not None:
            params['init_lr'] = float(args.init_lr)
        if args.lr_reduce_factor is not None:
            params['lr_reduce_factor'] = float(args.lr_reduce_factor)
        if args.lr_schedule_patience is not None:
            params['lr_schedule_patience'] = int(args.lr_schedule_patience)
        if args.min_lr is not None:
            params['min_lr'] = float(args.min_lr)
        if args.weight_decay is not None:
            params['weight_decay'] = float(args.weight_decay)
        if args.print_epoch_interval is not None:
            params['print_epoch_interval'] = int(args.print_epoch_interval)
        if args.max_time is not None:
            params['max_time'] = float(args.max_time)

        # network parameters
        net_params = config['net_params']
        net_params['device'] = device
        net_params['gpu_id'] = config['gpu']['id']
        net_params['batch_size'] = params['batch_size']
        if args.L is not None:
            net_params['L'] = int(args.L)
        if args.hidden_dim is not None:
            net_params['hidden_dim'] = int(args.hidden_dim)
        if args.out_dim is not None:
            net_params['out_dim'] = int(args.out_dim)   
        if args.residual is not None:
            net_params['residual'] = True if args.residual=='True' else False
        if args.edge_feat is not None:
            net_params['edge_feat'] = True if args.edge_feat=='True' else False
        if args.readout is not None:
            net_params['readout'] = args.readout
        if args.kernel is not None:
            net_params['kernel'] = int(args.kernel)
        if args.n_heads is not None:
            net_params['n_heads'] = int(args.n_heads)
        if args.gated is not None:
            net_params['gated'] = True if args.gated=='True' else False
        if args.in_feat_dropout is not None:
            net_params['in_feat_dropout'] = float(args.in_feat_dropout)
        if args.dropout is not None:
            net_params['dropout'] = float(args.dropout)
        if args.layer_norm is not None:
            net_params['layer_norm'] = True if args.layer_norm=='True' else False
        if args.batch_norm is not None:
            net_params['batch_norm'] = True if args.batch_norm=='True' else False
        if args.sage_aggregator is not None:
            net_params['sage_aggregator'] = args.sage_aggregator
        if args.data_mode is not None:
            net_params['data_mode'] = args.data_mode
        if args.num_pool is not None:
            net_params['num_pool'] = int(args.num_pool)
        if args.gnn_per_block is not None:
            net_params['gnn_per_block'] = int(args.gnn_per_block)
        if args.embedding_dim is not None:
            net_params['embedding_dim'] = int(args.embedding_dim)
        if args.pool_ratio is not None:
            net_params['pool_ratio'] = float(args.pool_ratio)
        if args.linkpred is not None:
            net_params['linkpred'] = True if args.linkpred=='True' else False
        if args.cat is not None:
            net_params['cat'] = True if args.cat=='True' else False
        if args.self_loop is not None:
            net_params['self_loop'] = True if args.self_loop=='True' else False
        if args.pos_enc is not None:
            net_params['pos_enc'] = True if args.pos_enc=='True' else False
        if args.pos_enc_dim is not None:
            net_params['pos_enc_dim'] = int(args.pos_enc_dim)

            
    # notebook mode
    if notebook_mode:
        
        # parameters
        params = config['params']
        
        # dataset
        DATASET_NAME = config['dataset']
        dataset = LoadData(DATASET_NAME)
        
        # device
        device = gpu_setup(config['gpu']['use'], config['gpu']['id'])
        out_dir = config['out_dir']
        
        # GNN model
        MODEL_NAME = config['model']
        
        # network parameters
        net_params = config['net_params']
        net_params['device'] = device
        net_params['gpu_id'] = config['gpu']['id']
        net_params['batch_size'] = params['batch_size']
        
            
    # SBM
    net_params['in_dim'] = torch.unique(dataset.train[0][0].ndata['feat'],dim=0).size(0) # node_dim (feat is an integer)
    net_params['n_classes'] = torch.unique(dataset.train[0][1],dim=0).size(0)
    
    if MODEL_NAME == 'RingGNN':
        num_nodes = [dataset.train[i][0].number_of_nodes() for i in range(len(dataset.train))]
        net_params['avg_node_num'] = int(np.ceil(np.mean(num_nodes)))

    root_log_dir = out_dir + 'logs/' + MODEL_NAME + "_" + DATASET_NAME + "_GPU" + str(config['gpu']['id']) + "_" + time.strftime('%Hh%Mm%Ss_on_%b_%d_%Y')
    root_ckpt_dir = out_dir + 'checkpoints/' + MODEL_NAME + "_" + DATASET_NAME + "_GPU" + str(config['gpu']['id']) + "_" + time.strftime('%Hh%Mm%Ss_on_%b_%d_%Y')
    write_file_name = out_dir + 'results/result_' + MODEL_NAME + "_" + DATASET_NAME + "_GPU" + str(config['gpu']['id']) + "_" + time.strftime('%Hh%Mm%Ss_on_%b_%d_%Y')
    write_config_file = out_dir + 'configs/config_' + MODEL_NAME + "_" + DATASET_NAME + "_GPU" + str(config['gpu']['id']) + "_" + time.strftime('%Hh%Mm%Ss_on_%b_%d_%Y')
    dirs = root_log_dir, root_ckpt_dir, write_file_name, write_config_file

    if not os.path.exists(out_dir + 'results'):
        os.makedirs(out_dir + 'results')
        
    if not os.path.exists(out_dir + 'configs'):
        os.makedirs(out_dir + 'configs')

    net_params['total_param'] = view_model_param(MODEL_NAME, net_params)
    train_val_pipeline(MODEL_NAME, dataset, params, net_params, dirs)

    
    
    
    
    
if notebook_mode==True:
    
    config = {}
    # gpu config
    gpu = {}
    gpu['use'] = use_gpu
    gpu['id'] = gpu_id
    config['gpu'] = gpu
    # GNN model, dataset, out_dir
    config['model'] = MODEL_NAME
    config['dataset'] = DATASET_NAME
    config['out_dir'] = out_dir
    # parameters
    params = {}
    params['seed'] = seed
    params['epochs'] = epochs
    params['batch_size'] = batch_size
    params['init_lr'] = init_lr
    params['lr_reduce_factor'] = lr_reduce_factor 
    params['lr_schedule_patience'] = lr_schedule_patience
    params['min_lr'] = min_lr
    params['weight_decay'] = weight_decay
    params['print_epoch_interval'] = 5
    params['max_time'] = max_time
    config['params'] = params
    # network parameters
    config['net_params'] = net_params
    
    # convert to .py format
    from utils.cleaner_main import *
    cleaner_main('main_SBMs_node_classification')
    
    main(True,config)
    
else:
    
    
    main()
# Out:
# Convert main_SBMs_node_classification.ipynb to main_SBMs_node_classification.py
# Clean main_SBMs_node_classification.py
# Done.
# [I] Loading dataset SBM_PATTERN...
# train, test, val sizes : 10000 2000 2000
# [I] Finished loading.
# [I] Data load time: 23.6980s
# cuda available with GPU: Tesla T4
# MODEL DETAILS:
#
# MODEL/Total parameters: GAT 110544
# GAT Selected
# Training Graphs:  10000
# Validation Graphs:  2000
# Test Graphs:  2000
# Number of Classes:  2
# Epoch 119: 100%|██████████| 120/120 [18:20<00:00,  9.17s/it, lr=5e-5, test_acc=70.9, time=9.41, train_acc=72, train_loss=0.547, val_acc=70.9, val_loss=0.563]
# Test Accuracy: 70.9474
# Train Accuracy: 72.3016
# Convergence Time (Epochs): 119.0000
# TOTAL TIME TAKEN: 1118.4761s
# AVG TIME PER EPOCH: 9.1617s
