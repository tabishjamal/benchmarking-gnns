# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#conda install git
#https://drive.google.com/drive/folders/1ESR7fUf1K4JPn8JFZyNvNQnIP5rXrY_r?usp=sharing
#https://drive.google.com/drive/folders/1ESR7fUf1K4JPn8JFZyNvNQnIP5rXrY_r?usp=sharing
#!wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1ESR7fUf1K4JPn8JFZyNvNQnIP5rXrY_r' -O benchmarking-gnns
# Out:
# --2021-06-23 08:53:21--  https://docs.google.com/uc?export=download&id=1ESR7fUf1K4JPn8JFZyNvNQnIP5rXrY_r
# Resolving docs.google.com (docs.google.com)... 74.125.206.139, 74.125.206.113, 74.125.206.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.206.139|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-06-23 08:53:21 ERROR 404: Not Found.

# %%
#/content/drive/MyDrive/Colab Notebooks/benchmarking-gnns

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %cp -av benchmarking-gnns /content
# Out:
# 'benchmarking-gnns' -> '/content/benchmarking-gnns'
# 'benchmarking-gnns/main_superpixels_graph_classification.py' -> '/content/benchmarking-gnns/main_superpixels_graph_classification.py'
# 'benchmarking-gnns/main_CSL_graph_classification.py' -> '/content/benchmarking-gnns/main_CSL_graph_classification.py'
# 'benchmarking-gnns/main_superpixels_graph_classification.ipynb' -> '/content/benchmarking-gnns/main_superpixels_graph_classification.ipynb'
# 'benchmarking-gnns/.gitignore' -> '/content/benchmarking-gnns/.gitignore'
# 'benchmarking-gnns/main_molecules_graph_regression.py' -> '/content/benchmarking-gnns/main_molecules_graph_regression.py'
# 'benchmarking-gnns/environment_cpu.yml' -> '/content/benchmarking-gnns/environment_cpu.yml'
# 'benchmarking-gnns/main_GraphTheoryProp_multitask.ipynb' -> '/content/benchmarking-gnns/main_GraphTheoryProp_multitask.ipynb'
# 'benchmarking-gnns/main_TUs_graph_classification.py' -> '/content/benchmarking-gnns/main_TUs_graph_classification.py'
# ...

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %ls
# Out:
# benchmarking-gnns/  BenchmarkingInstallation.ipynb

# %%
#!git clone -b master-dgl-0.6 https://github.com/graphdeeplearning/benchmarking-gnns.git
#%cd benchmarking-gnns
# %cd benchmarking-gnns
# Out:
# [Errno 2] No such file or directory: 'benchmarking-gnns'
# /content/drive/MyDrive/Colab Notebooks/benchmarking-gnns

# %%
conda env create -f environment_gpu.yml
# Out:
#   File "<ipython-input-12-dd79d8c08b59>", line 3
#     conda env create -f environment_gpu.yml
#             ^
# SyntaxError: invalid syntax

# %%
conda activate benchmark_gnn
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle

# %%
with open('benchmarking-gnns/data/SBMs/SBM_PATTERN.pkl',"rb") as f:
    graph_pattern = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-6dbea0080075> in <module>
#       1 with open('benchmarking-gnns/data/SBMs/SBM_PATTERN.pkl',"rb") as f:
# ----> 2     graph_pattern = pickle.load(f)
#
# ModuleNotFoundError: No module named 'data'

# %%
import dgl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-fd726d2cda90> in <module>
# ----> 1 import dgl
#
# ModuleNotFoundError: No module named 'dgl'

# %%
print(dgl.__version__)
# Out:
# 0.4.3

# %%
# !pip install dgl==0.4.2
# Out:
# ERROR: Could not find a version that satisfies the requirement dgl==0.4.2 (from versions: 0.4, 0.4.3, 0.4.3.post2, 0.5.0, 0.5.1, 0.5.2, 0.5.3, 0.6.0, 0.6.0.post1, 0.6.1)
# ERROR: No matching distribution found for dgl==0.4.2

# %%
# %cd benchmarking-gnns
# Out:
# /Users/tabishjamal/Drive/benchmarking-gnns

# %%
# !git checkout -b master-dgl-0.6
# Out:
# M	data/SBMs.py
# M	data/data.py
# M	main_SBMs_node_classification.ipynb
# Switched to a new branch 'master-dgl-0.6'
